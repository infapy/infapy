# %% [markdown]
# # GetSecurityLogs

# %% [markdown]
# Use this resource to receive security log entries. Security logs include information about events such as login actions and creating, updating, and deleting users, user groups, and roles. To use this resource, you must be logged in with an administrator role.

# %%
import infapy

infapy.setFileLogger(name="test",level="DEBUG")
infaHandler = infapy.connect(profile="DEV")

v3 = infaHandler.v3()
securityLogs = v3.getSecurityLogs()

# %% [markdown]
# ## Function: getSecurityLogsForLastOneDay()

# %% [markdown]
# >        getSecurityLogsForLastOneDay
# >
# >        Returns:
# >            list of dict: The response of the security logs in the last one day

# %%
lastOneDayLogs = securityLogs.getSecurityLogsForLastOneDay()
print(lastOneDayLogs)
# Out:
# {'entries': [{'id': '9vi3BMg6RnkltMTknVw7CB', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:39:58.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '2u7uadDPRgKlO2ebZ5SScI', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:40:00.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '36bWA5EDSJRgluQjqs2xcW', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:50:41.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '2VRyZeMulSbgwZQXdqZrmh', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:50:43.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '2Mrv1Obs5J6gt4nE1oV9Sc', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:50:56.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'cPDZC1B1SwTfCz3KUoi0ug', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:50:58.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'fDSlVlBi9GxhUchopWqJGf', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:51:17.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'cazEoGI9AkKgSIUvr5loKm', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:51:19.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'iloVsVqewcJemfeDadFxYC', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:55:10.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '7wTnMZSL6iyij9HDU6zMA1', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:55:12.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '8yqEzkEOd1ik8gOTJEJXi3', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:55:19.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '67SCVS4YBWxhLlYsTBkzie', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:55:21.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '6OVz1ZXaPYtbi6jb1ZwHQ4', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T20:01:55.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '2hgu0jN5qeUeFQWYVPygmr', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T20:01:57.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '2IZqZgCeb08laupjTlISKI', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T20:02:05.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN' ...

# %% [markdown]
# ## Function: getSecurityLogsByCustomQuery()

# %% [markdown]
# >        getSecurityLogsByCustomQuery
# >
# >        Args:
# >            query (String): Pass the query string
# >
# >        Returns:
# >            list of dict: The response of the security logs in json
#
# To build the Query. Review the product docs
# https://docs.informatica.com/integration-cloud/cloud-platform/current-version/rest-api-reference/platform-rest-api-version-3-resources/securitylog.html

# %%
query = "entryTime>=\"2021-09-25T08:00:00.000Z\";entryTime<=\"2021-09-26T17:00:00.000Z\""
print(query)

response = securityLogs.getSecurityLogsByCustomQuery(query=query)
print(response)
# Out:
# entryTime>="2021-09-25T08:00:00.000Z";entryTime<="2021-09-26T17:00:00.000Z"
# {'entries': [{'id': '8TOSTm9IFAmiC6JlfgfTsW', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:00:58.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '6yQelEBNz6XimCmsgplmWf', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:01:00.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'bScaVdDSLKHiPksdIhLh2d', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:01:55.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '0JLv7iSk9Lhfif3bz7Ruee', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:01:57.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'gxMhCoOo1ybfMpARb538YG', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:05:30.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'bDN6tmpW0mzjZTLBHSiZAM', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:05:32.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '4gLP4HJx6I1hGRrmpBv6WJ', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:06:40.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '5rLY2GserachpkyoigiwQM', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:06:42.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '03CZdlzRJC2foIvKvrNXuR', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:07:14.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '0X2AhWPQO96g9wQsMDAw4i', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:07:15.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'kHhm30rzbWwchXLMNGTSkI', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:08:39.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '0RrZPYts5Afb8mAvsRQQM2', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:08:41.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': 'aCinuhI4zKgiLSsRsKguUD', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:11:34.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '7wWWiaHZbEgb2jlCDwsuwh', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T08:23:48.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'User', 'actionEvent': 'LOGOUT'}, {'id': '9vi3BMg6RnkltMTknVw7CB', 'orgId': 'fg1dzqDZ1K3lbHp8uq5vQB', 'actor': 'prashanth-p', 'entryTime': '2021-09-25T19:39:58.000Z', 'objectId': '42szaouMf0bg0yycPME0Up', 'objectName': 'prashanth-p', 'actionCategory': 'Authentication', 'actionEvent': 'USER_LOGIN'}, {'id': '2u7 ...
